# %% [markdown]
# [toc]
# # 妙语连珠
# Conformity to patterns is not a measure of goodness.
#
# 程序设计语言的选择非常重要，它将影响人们理解问题的出发点。
# The choice of programming language is important because it influences one’s point of
# view.
# # misc
#
# ## chap 06
# 在 Python 中，模块也是一等对象，而且标准库提供了几个处理模块的函数
#
# 使用一等函数（和其他动态特性）简化几个经典的设计模式

# %% [markdown]
# d = [1, 2, 3, 4, 5]

# %% [markdown]
# ![dp.png](attachment:dp.png)
